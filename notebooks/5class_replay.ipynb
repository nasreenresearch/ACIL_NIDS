# %% [markdown]
# # Replay Strategy - 5 class grouped

# %%
#basic imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.preprocessing import MinMaxScaler as MMS
#torch
import torch
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.optim import SGD
from torch.nn import CrossEntropyLoss
from torch.nn import MSELoss
from torch.nn import BCEWithLogitsLoss,BCELoss

#avalanche
from avalanche.models import SimpleMLP,MlpVAE,SlimResNet18,IcarlNet #model
from avalanche.training.supervised import Naive,Cumulative,Replay,LwF,ICaRL #cl strat
from avalanche.benchmarks.generators import nc_benchmark,ni_benchmark #custom benchmark
from avalanche.evaluation.metrics import forgetting_metrics, accuracy_metrics,loss_metrics, timing_metrics, cpu_usage_metrics, confusion_matrix_metrics, disk_usage_metrics #metrics
from avalanche.logging import InteractiveLogger, TextLogger, TensorboardLogger, CSVLogger #loggers
from avalanche.training.plugins import EvaluationPlugin

# %%
df_train=pd.read_csv('../data/fiveclass_train.csv')
df_train=df_train.drop(['Fwd Avg Bytes/Bulk','Fwd Avg Bulk Rate','Bwd Avg Bytes/Bulk','Bwd PSH Flags','Bwd URG Flags','Bwd Avg Bulk Rate','Fwd Avg Packets/Bulk','Bwd Avg Packets/Bulk'],axis=1)
df_test=pd.read_csv('../data/fiveclass_test.csv')
df_test=df_test.drop(['Fwd Avg Bytes/Bulk','Fwd Avg Bulk Rate','Bwd Avg Bytes/Bulk','Bwd PSH Flags','Bwd URG Flags','Bwd Avg Bulk Rate','Fwd Avg Packets/Bulk','Bwd Avg Packets/Bulk'],axis=1)

# %%
df_train.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                80      6018089.0                  5                       3
# 1               443       323049.0                  8                       6
# 2                80     39270118.0                  9                      10
# 3              4848           43.0                  1                       1
# 4                80      5754816.0                  3                       1
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                          177                          994
# 1                          531                         3208
# 2                          898                         3944
# 3                            2                            6
# 4                           12                            0
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                    159                      0               35.400000
# 1                    194                      0               66.375000
# 2                    431                      0               99.777778
# 3                      2                      2                2.000000
# 4                      6                      0                4.000000
#
#    Fwd Packet Length Std  ...  Active Mean  Active Std  Active Max  \
# 0              69.143329  ...  275923.0000       0.000      275923
# 1              85.880211  ...       0.0000       0.000           0
# 2             187.795619  ...  123253.6667  149943.928      296394
# 3               0.000000  ...       0.0000       0.000           0
# 4               3.464102  ...       0.0000       0.000           0
#
#    Active Min   Idle Mean    Idle Std  Idle Max  Idle Min  Label  fiveLabels
# 0      275923   5742166.0    0.000000   5742166   5742166      0           0
# 1           0         0.0    0.000000         0         0      0           0
# 2       36667  10000000.0  300.561142  10000000   9999980      0           0
# 3           0         0.0    0.000000         0         0     10           3
# 4           0         0.0    0.000000         0         0      0           0
#
# [5 rows x 72 columns]

# %% [markdown]
# # Load Data

# %%
x_train=df_train.drop(['Label','fiveLabels'],axis=1)
y_train=df_train.fiveLabels
x_test=df_test.drop(['Label','fiveLabels'],axis=1)
y_test=df_test.fiveLabels
x_train.shape,x_test.shape,y_train.shape
x_train=x_train.values
x_test=x_test.values
y_train=y_train.values
y_test=y_test.values

# %% [markdown]
# # Create Benchmarks

# %%
mms=MMS(feature_range=(0,1))
x_train=mms.fit_transform(x_train)
x_test=mms.fit_transform(x_test)
x_train=torch.tensor(x_train,dtype=torch.float32)
y_train=torch.tensor(y_train)
x_test=torch.tensor(x_test,dtype=torch.float32)
y_test=torch.tensor(y_test)

# %%
type(x_train)
# Out:
# torch.Tensor

# %%
train_dataset=TensorDataset(x_train,y_train)
test_dataset=TensorDataset(x_test,y_test)
NC_benchmark = nc_benchmark(train_dataset=train_dataset,test_dataset = test_dataset,n_experiences=6,task_labels=False,shuffle=False,fixed_class_order=[0,1,3,2,5,4])
#NI_benchmark=ni_benchmark(train_dataset=train_dataset,test_dataset = test_dataset,n_experiences=1,task_labels=False,seed=1234)

# %%
x_train[0].dim(),y_train.dim()
# Out:
# (1, 1)

# %% [markdown]
# # Attempt SimpleMLP

# %%
model_2=SimpleMLP(num_classes=6,input_size=70)

# %%
text_logger = TextLogger(open('./logs/Replay_fiveclass.txt', 'a'))
interactive_logger = InteractiveLogger()
csv_logger=CSVLogger("./logs/Replay_fiveclass.csv")


eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    timing_metrics(epoch=True, epoch_running=True),
    forgetting_metrics(experience=True, stream=True),
    confusion_matrix_metrics(num_classes=NC_benchmark.n_classes, save_image=False,
                             stream=True),
    loggers=[interactive_logger, text_logger,csv_logger]
)
# Strategy
cl_strategy = Replay(
    model_2, Adam(model_2.parameters(), lr=0.001),
    CrossEntropyLoss(), train_mb_size=256, train_epochs=1, eval_mb_size=300,
    evaluator=eval_plugin)

# %%
y_train[0].size()
# Out:
# torch.Size([])

# %%
print('Starting experiment...')
results = []
for experience in NC_benchmark.train_stream:
    print("Start of experience: ", experience.current_experience)
    print("Current Classes: ", experience.classes_in_this_experience)

    # train returns a dictionary which contains all the metric values
    res = cl_strategy.train(experience)
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(NC_benchmark.test_stream))
# Out:
# Starting experiment...
# Start of experience:  0
# Current Classes:  [0]
# -- >> Start of training phase << --
# 100%|██████████| 7104/7104 [00:44<00:00, 158.22it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0055
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0000
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Time_Epoch/train_phase/train_stream/Task000 = 44.9470
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9997
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:09<00:00, 152.68it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 1.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 151.40it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 52.7013
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 157.56it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 23.3605
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 150.15it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 46.3156
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 145.34it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 26.3996
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 169.64it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 26.7446
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[454620,      0,      0,      0,      0,      0],
#         [ 50537,      0,      0,      0,      0,      0],
#         [ 25999,      0,      0,      0,      0,      0],
#         [ 31795,      0,      0,      0,      0,      0],
#         [  1309,      0,      0,      0,      0,      0],
#         [  1889,      0,      0,      0,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 8.2931
# 	StreamForgetting/eval_phase/test_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.8030
# Start of experience:  1
# Current Classes:  [1]
# -- >> Start of training phase << --
# 100%|██████████| 790/790 [00:07<00:00, 98.86it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.5739
# 	Loss_MB/train_phase/train_stream/Task000 = 0.1263
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Time_Epoch/train_phase/train_stream/Task000 = 7.9909
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8547
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9584
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:11<00:00, 126.61it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.0694
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2004
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9306
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 125.57it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0551
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.9850
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 132.93it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 20.2021
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 133.58it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 30.3098
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 148.37it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 15.5418
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 151.68it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 17.3247
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[423071,  31549,      0,      0,      0,      0],
#         [   757,  49780,      0,      0,      0,      0],
#         [   392,  25607,      0,      0,      0,      0],
#         [ 31760,     35,      0,      0,      0,      0],
#         [  1302,      7,      0,      0,      0,      0],
#         [  1657,    232,      0,      0,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 2.7842
# 	StreamForgetting/eval_phase/test_stream = 0.0694
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.8352
# Start of experience:  2
# Current Classes:  [3]
# -- >> Start of training phase << --
# 100%|██████████| 497/497 [00:06<00:00, 81.16it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 1.3125
# 	Loss_MB/train_phase/train_stream/Task000 = 0.1602
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0002
# 	Time_Epoch/train_phase/train_stream/Task000 = 6.1217
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7919
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9557
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:14<00:00, 107.75it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.1209
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3187
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8791
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 127.27it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.0206
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.1597
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.9645
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 128.70it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0513
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.9987
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 124.84it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 46.8580
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 148.42it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 12.9550
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 163.57it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 17.5300
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[399675,  27499,      0,  27446,      0,      0],
#         [  1417,  48741,      0,    379,      0,      0],
#         [   166,  25597,      0,    236,      0,      0],
#         [    12,     30,      0,  31753,      0,      0],
#         [  1167,      9,      0,    133,      0,      0],
#         [    51,    790,      0,   1048,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 2.5086
# 	StreamForgetting/eval_phase/test_stream = 0.0707
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.8481
# Start of experience:  3
# Current Classes:  [2]
# -- >> Start of training phase << --
# 100%|██████████| 407/407 [00:04<00:00, 88.16it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 3.6045
# 	Loss_MB/train_phase/train_stream/Task000 = 0.3763
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0002
# 	Time_Epoch/train_phase/train_stream/Task000 = 4.6150
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.6940
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.8798
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:12<00:00, 117.99it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.1402
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4875
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8598
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 119.05it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.2939
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.9401
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.6911
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 116.98it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 0.0085
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 0.1258
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.9902
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 121.61it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 0.1352
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.9775
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 149.57it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 15.6833
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 141.60it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 11.4308
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[390863,  11624,  27393,  24740,      0,      0],
#         [  1815,  34928,  13437,    357,      0,      0],
#         [   165,    184,  25414,    236,      0,      0],
#         [   259,     24,     30,  31482,      0,      0],
#         [  1295,      3,      6,      5,      0,      0],
#         [   303,    788,      2,    796,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 0.5674
# 	StreamForgetting/eval_phase/test_stream = 0.1475
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.8526
# Start of experience:  4
# Current Classes:  [5]
# -- >> Start of training phase << --
# 100%|██████████| 30/30 [00:00<00:00, 58.13it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 6.9302
# 	Loss_MB/train_phase/train_stream/Task000 = 3.7316
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0036
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.5158
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3963
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.5482
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:13<00:00, 115.32it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.2052
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5850
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7948
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:02<00:00, 71.86it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.2288
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.7715
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.7562
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:01<00:00, 94.55it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 0.0047
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 0.1372
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.9940
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:01<00:00, 79.81it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp003 = 0.0103
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 0.1813
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.9672
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 113.25it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 8.8857
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 88.08it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 7.2691
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[361348,  16626,  49951,  26695,      0,      0],
#         [  1232,  38215,  10749,    341,      0,      0],
#         [   108,    507,  25145,    239,      0,      0],
#         [   141,     18,     31,  31605,      0,      0],
#         [   122,    236,    575,    376,      0,      0],
#         [   257,    800,     35,    797,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 0.6011
# 	StreamForgetting/eval_phase/test_stream = 0.1123
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.8060
# Start of experience:  5
# Current Classes:  [4]
# -- >> Start of training phase << --
# 100%|██████████| 21/21 [00:00<00:00, 50.33it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 4.2573
# 	Loss_MB/train_phase/train_stream/Task000 = 2.8794
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0066
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.4170
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3183
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.4500
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:15<00:00, 98.73it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.2139
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6257
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7861
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 101.33it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.2138
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.7099
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.7712
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 114.94it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 0.0047
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 0.1563
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.9940
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 97.34it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp003 = 0.0281
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 0.2575
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.9494
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 121.27it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp004 = 0.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 6.1070
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 138.70it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 5.1277
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[357376,  17345,  54123,  25776,      0,      0],
#         [  1228,  38973,   9996,    340,      0,      0],
#         [   107,    970,  24683,    239,      0,      0],
#         [   141,     18,     31,  31605,      0,      0],
#         [   125,    601,    575,      8,      0,      0],
#         [   805,    253,     35,    796,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 0.6186
# 	StreamForgetting/eval_phase/test_stream = 0.0921
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.7995

# %%
torch.__version__
# Out:
# '1.13.1'
