# %% [markdown]
# # Naive Strategy - 5 Class Grouped

# %%
#basic imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.preprocessing import MinMaxScaler as MMS
#torch
import torch
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.optim import SGD
from torch.nn import CrossEntropyLoss
from torch.nn import MSELoss
from torch.nn import BCEWithLogitsLoss,BCELoss

#avalanche
from avalanche.models import SimpleMLP,MlpVAE,SlimResNet18,IcarlNet #model
from avalanche.training.supervised import Naive,Cumulative,Replay,LwF,ICaRL #cl strat
from avalanche.benchmarks.generators import nc_benchmark,ni_benchmark #custom benchmark
from avalanche.evaluation.metrics import forgetting_metrics, accuracy_metrics,loss_metrics, timing_metrics, cpu_usage_metrics, confusion_matrix_metrics, disk_usage_metrics #metrics
from avalanche.logging import InteractiveLogger, TextLogger, TensorboardLogger, CSVLogger #loggers
from avalanche.training.plugins import EvaluationPlugin

# %%
df_train=pd.read_csv('../data/fiveclass_train.csv')
df_train=df_train.drop(['Fwd Avg Bytes/Bulk','Fwd Avg Bulk Rate','Bwd Avg Bytes/Bulk','Bwd PSH Flags','Bwd URG Flags','Bwd Avg Bulk Rate','Fwd Avg Packets/Bulk','Bwd Avg Packets/Bulk'],axis=1)
df_test=pd.read_csv('../data/fiveclass_test.csv')
df_test=df_test.drop(['Fwd Avg Bytes/Bulk','Fwd Avg Bulk Rate','Bwd Avg Bytes/Bulk','Bwd PSH Flags','Bwd URG Flags','Bwd Avg Bulk Rate','Fwd Avg Packets/Bulk','Bwd Avg Packets/Bulk'],axis=1)

# %%
df_train.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                80      6018089.0                  5                       3
# 1               443       323049.0                  8                       6
# 2                80     39270118.0                  9                      10
# 3              4848           43.0                  1                       1
# 4                80      5754816.0                  3                       1
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                          177                          994
# 1                          531                         3208
# 2                          898                         3944
# 3                            2                            6
# 4                           12                            0
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                    159                      0               35.400000
# 1                    194                      0               66.375000
# 2                    431                      0               99.777778
# 3                      2                      2                2.000000
# 4                      6                      0                4.000000
#
#    Fwd Packet Length Std  ...  Active Mean  Active Std  Active Max  \
# 0              69.143329  ...  275923.0000       0.000      275923
# 1              85.880211  ...       0.0000       0.000           0
# 2             187.795619  ...  123253.6667  149943.928      296394
# 3               0.000000  ...       0.0000       0.000           0
# 4               3.464102  ...       0.0000       0.000           0
#
#    Active Min   Idle Mean    Idle Std  Idle Max  Idle Min  Label  fiveLabels
# 0      275923   5742166.0    0.000000   5742166   5742166      0           0
# 1           0         0.0    0.000000         0         0      0           0
# 2       36667  10000000.0  300.561142  10000000   9999980      0           0
# 3           0         0.0    0.000000         0         0     10           3
# 4           0         0.0    0.000000         0         0      0           0
#
# [5 rows x 72 columns]

# %% [markdown]
# # Load Data

# %%
x_train=df_train.drop(['Label','fiveLabels'],axis=1)
y_train=df_train.fiveLabels
x_test=df_test.drop(['Label','fiveLabels'],axis=1)
y_test=df_test.fiveLabels
x_train.shape,x_test.shape,y_train.shape
x_train=x_train.values
x_test=x_test.values
y_train=y_train.values
y_test=y_test.values

# %% [markdown]
# # Create Benchmarks

# %%
mms=MMS(feature_range=(0,1))
x_train=mms.fit_transform(x_train)
x_test=mms.fit_transform(x_test)
x_train=torch.tensor(x_train,dtype=torch.float32)
y_train=torch.tensor(y_train)
x_test=torch.tensor(x_test,dtype=torch.float32)
y_test=torch.tensor(y_test)

# %%
type(x_train)
# Out:
# torch.Tensor

# %%
train_dataset=TensorDataset(x_train,y_train)
test_dataset=TensorDataset(x_test,y_test)
NC_benchmark = nc_benchmark(train_dataset=train_dataset,test_dataset = test_dataset,n_experiences=6,task_labels=False,shuffle=False,fixed_class_order=[0,1,3,2,5,4])
#NI_benchmark=ni_benchmark(train_dataset=train_dataset,test_dataset = test_dataset,n_experiences=1,task_labels=False,seed=1234)

# %%
x_train[0].dim(),y_train.dim()
# Out:
# (1, 1)

# %% [markdown]
# # Attempt SimpleMLP

# %%
model_2=SimpleMLP(num_classes=6,input_size=70)

# %%
text_logger = TextLogger(open('./logs/Naive_fiveclass.txt', 'a'))
interactive_logger = InteractiveLogger()
csv_logger=CSVLogger("./logs/Naive_fiveclass.csv")


eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    timing_metrics(epoch=True, epoch_running=True),
    forgetting_metrics(experience=True, stream=True),
    confusion_matrix_metrics(num_classes=NC_benchmark.n_classes, save_image=False,
                             stream=True),
    loggers=[interactive_logger, text_logger,csv_logger]
)
# Strategy
cl_strategy = Naive(
    model_2, Adam(model_2.parameters(), lr=0.001),
    CrossEntropyLoss(), train_mb_size=256, train_epochs=1, eval_mb_size=300,
    evaluator=eval_plugin)

# %%
y_train[0].size()
# Out:
# torch.Size([])

# %%
print('Starting experiment...')
results = []
for experience in NC_benchmark.train_stream:
    print("Start of experience: ", experience.current_experience)
    print("Current Classes: ", experience.classes_in_this_experience)

    # train returns a dictionary which contains all the metric values
    res = cl_strategy.train(experience)
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(NC_benchmark.test_stream))
# Out:
# Starting experiment...
# Start of experience:  0
# Current Classes:  [0]
# -- >> Start of training phase << --
# 100%|██████████| 7104/7104 [00:47<00:00, 150.38it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 0.0056
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0000
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Time_Epoch/train_phase/train_stream/Task000 = 47.2406
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9998
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:11<00:00, 128.95it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 1.0000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 134.62it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 55.4501
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 137.67it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 23.2493
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 134.88it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 48.1801
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 107.22it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 25.9343
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 153.26it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 26.6864
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[454620,      0,      0,      0,      0,      0],
#         [ 50537,      0,      0,      0,      0,      0],
#         [ 25999,      0,      0,      0,      0,      0],
#         [ 31795,      0,      0,      0,      0,      0],
#         [  1309,      0,      0,      0,      0,      0],
#         [  1889,      0,      0,      0,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 8.6162
# 	StreamForgetting/eval_phase/test_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.8030
# Start of experience:  1
# Current Classes:  [1]
# -- >> Start of training phase << --
# 100%|██████████| 790/790 [00:06<00:00, 131.04it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.7344
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0005
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Time_Epoch/train_phase/train_stream/Task000 = 6.0286
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8691
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:11<00:00, 129.01it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.9996
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 9.6058
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0004
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 131.66it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0001
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 1.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 123.78it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 19.8106
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 124.54it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 33.1298
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 143.73it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 21.5807
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 135.79it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 21.5443
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[   203, 454417,      0,      0,      0,      0],
#         [     0,  50537,      0,      0,      0,      0],
#         [     0,  25999,      0,      0,      0,      0],
#         [     0,  31795,      0,      0,      0,      0],
#         [     0,   1309,      0,      0,      0,      0],
#         [     0,   1889,      0,      0,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 10.4693
# 	StreamForgetting/eval_phase/test_stream = 0.9996
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0896
# Start of experience:  2
# Current Classes:  [3]
# -- >> Start of training phase << --
# 100%|██████████| 497/497 [00:04<00:00, 103.74it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.0652
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0114
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0001
# 	Time_Epoch/train_phase/train_stream/Task000 = 4.7898
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7372
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:12<00:00, 118.41it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.9991
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 8.6279
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0009
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 123.42it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.9676
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 6.2869
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0324
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 124.96it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0042
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 1.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 115.42it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 26.8699
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 131.42it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 17.3644
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 143.76it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 17.3117
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[   424,   4351,      0, 449845,      0,      0],
#         [     0,   1636,      0,  48901,      0,      0],
#         [     0,      3,      0,  25996,      0,      0],
#         [     0,      0,      0,  31795,      0,      0],
#         [     0,      0,      0,   1309,      0,      0],
#         [     0,      0,      0,   1889,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 8.8216
# 	StreamForgetting/eval_phase/test_stream = 0.9833
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0598
# Start of experience:  3
# Current Classes:  [2]
# -- >> Start of training phase << --
# 100%|██████████| 407/407 [00:03<00:00, 118.13it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 2.6361
# 	Loss_MB/train_phase/train_stream/Task000 = 0.0038
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Time_Epoch/train_phase/train_stream/Task000 = 3.4455
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7532
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:13<00:00, 113.15it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.9996
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 6.3636
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0004
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 100.85it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 17.7752
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:01<00:00, 99.37it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 3.4604
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 110.65it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0018
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 1.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 141.09it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 12.7469
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 146.13it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 13.4117
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[   203,      0, 454417,      0,      0,      0],
#         [     0,      0,  50537,      0,      0,      0],
#         [     0,      0,  25999,      0,      0,      0],
#         [     0,      0,  31795,      0,      0,      0],
#         [     0,      0,   1309,      0,      0,      0],
#         [     0,      0,   1889,      0,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 6.9646
# 	StreamForgetting/eval_phase/test_stream = 0.9999
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0463
# Start of experience:  4
# Current Classes:  [5]
# -- >> Start of training phase << --
# 100%|██████████| 30/30 [00:00<00:00, 78.46it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 10.0084
# 	Loss_MB/train_phase/train_stream/Task000 = 7.6406
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0015
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.3818
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:13<00:00, 109.46it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.9995
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 4.9319
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0005
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 115.11it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 14.8783
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:01<00:00, 97.63it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 3.1333
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 114.98it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp003 = 0.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0043
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 1.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 140.85it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 7.5611
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 116.25it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 10.3529
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[   209,      0, 454411,      0,      0,      0],
#         [     1,      0,  50536,      0,      0,      0],
#         [     0,      0,  25999,      0,      0,      0],
#         [     0,      0,  31795,      0,      0,      0],
#         [     0,      0,   1309,      0,      0,      0],
#         [     0,      0,   1889,      0,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 5.5138
# 	StreamForgetting/eval_phase/test_stream = 0.7499
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0463
# Start of experience:  5
# Current Classes:  [4]
# -- >> Start of training phase << --
# 100%|██████████| 21/21 [00:00<00:00, 113.03it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream/Task000 = 8.9392
# 	Loss_MB/train_phase/train_stream/Task000 = 7.5752
# 	RunningTime_Epoch/train_phase/train_stream/Task000 = 0.0009
# 	Time_Epoch/train_phase/train_stream/Task000 = 0.1853
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0000
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.0000
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 1516/1516 [00:14<00:00, 103.22it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.9921
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 4.0639
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0079
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 169/169 [00:01<00:00, 107.05it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp001 = 0.9689
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp001 = 12.7303
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0311
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 106/106 [00:00<00:00, 110.08it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp002 = 1.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp002 = 2.7266
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 87/87 [00:00<00:00, 117.63it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp003 = 0.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0092
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 1.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 7/7 [00:00<00:00, 120.67it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp004 = 0.0000
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp004 = 5.9865
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 129.17it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp005 = 7.6523
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- >> End of eval phase << --
# 	ConfusionMatrix_Stream/eval_phase/test_stream =
# tensor([[  3572,   1536, 449510,      2,      0,      0],
#         [     1,   1573,  48963,      0,      0,      0],
#         [     0,      0,  25999,      0,      0,      0],
#         [     0,      0,  31795,      0,      0,      0],
#         [     0,      0,   1309,      0,      0,      0],
#         [     0,      0,   1889,      0,      0,      0]])
# 	Loss_Stream/eval_phase/test_stream/Task000 = 4.5909
# 	StreamForgetting/eval_phase/test_stream = 0.5922
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0550

# %%
torch.__version__
# Out:
# '1.13.1'
